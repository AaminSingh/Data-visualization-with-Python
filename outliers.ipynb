# %%
data={'profession':['doctor','engineer','actor','director','footballer','freelancer','teacher'],
      'salary(usd)':[500000,400000,69000000,10000000,30000000,20000,100000],
      'work_hours':[10,8,5,6,12,3,8],
      'age':[65,24,30,32,22,18,35]}

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
data={"Temperature":[50,32,31,41,40],
"days":['mon','tue','wed','thurs','fri']}
df=pd.DataFrame(data)
Temperature =np.random.randint(25,45,size=10)
sns.lineplot(x='days',y='Temperature',data=df)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
fig,ax=plt.subplots()
x=np.linspace(1,10,100)
y_sine=np.sin(x)
y_cos=np.cos(x)
ax.plot(x,y_sine) 
ax.plot(x,y_cos)
plt.show()
